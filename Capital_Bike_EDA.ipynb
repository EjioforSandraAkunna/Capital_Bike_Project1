# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
day=pd.read_csv(r"/Users/sandraakunnaejiofor/Documents/CODE ACADEMY BERLIN/Capital_Bike_Project/day.csv",parse_dates=["dteday"])
hour=pd.read_csv(r"/Users/sandraakunnaejiofor/Documents/CODE ACADEMY BERLIN/Capital_Bike_Project/hour.csv",parse_dates=["dteday"])

# %%
day.shape
# Out:
# (731, 16)

# %%
hour.shape
# Out:
# (17379, 17)

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %%
day.info()
day.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1        0        6           0
# 1        2 2011-01-02       1   0     1        0        0           0
# 2        3 2011-01-03       1   0     1        0        1           1
# 3        4 2011-01-04       1   0     1        0        2           1
# 4        5 2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour.info()
hour.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01       1   0     1   0        0        6           0
# 1        2 2011-01-01       1   0     1   1        0        6           0
# 2        3 2011-01-01       1   0     1   2        0        6           0
# 3        4 2011-01-01       1   0     1   3        0        6           0
# 4        5 2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
hour.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
day.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
hour.loc[hour["season"]==1,"season"]="Winter"
hour.loc[hour["season"]==2,"season"]="Spring"
hour.loc[hour["season"]==3,"season"]="Summer"
hour.loc[hour["season"]==4,"season"]="Fall"

# %%
day.loc[day["season"]==1,"season"]="Winter"
day.loc[day["season"]==2,"season"]="Spring"
day.loc[day["season"]==3,"season"]="Summer"
day.loc[day["season"]==4,"season"]="Fall"

# %%
pd.to_datetime(hour["dteday"])
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 17374   2012-12-31
# 17375   2012-12-31
# 17376   2012-12-31
# 17377   2012-12-31
# 17378   2012-12-31
# Name: dteday, Length: 17379, dtype: datetime64[ns]

# %%
day["season"]=pd.Categorical(day["season"],categories=("Winter","Spring","Summer","Fall"))
day["is_holiday"]=day["holiday"]
day.loc[day["is_holiday"]==1,"is_holiday"]="Yes"
day.loc[day["is_holiday"]==0,"is_holiday"]="No"
day["is_holiday"]=pd.Categorical(day["is_holiday"],categories=("Yes","No"))

# %%
hour["season"]=pd.Categorical(hour["season"],categories=("Winter","Spring","Summer","Fall"))
hour["is_holiday"]=hour["holiday"]
hour.loc[hour["is_holiday"]==1,"is_holiday"]="Yes"
hour.loc[hour["is_holiday"]==0,"is_holiday"]="No"
hour["is_holiday"]=pd.Categorical(hour["is_holiday"],categories=("Yes","No"))

# %%
day["tem_cel"]=np.ceil(day["temp"]*47-8).astype(int)
day["atemp_cel"]=np.ceil(day["temp"]*66-16).astype(int)
day["windspeed_"]=np.ceil(day["windspeed"]*67).astype(int)

# %%
hour["tem_cel"]=np.ceil(hour["temp"]*47-8).astype(int)
hour["atemp_cel"]=np.ceil(hour["temp"]*66-16).astype(int)
hour["windspeed_"]=np.ceil(hour["windspeed"]*67).astype(int)

# %%
hour.describe()
# Out:
#           instant            yr          mnth            hr       holiday  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      0.502561      6.537775     11.546752      0.028770
# std     5017.0295      0.500008      3.438776      6.914405      0.167165
# min        1.0000      0.000000      1.000000      0.000000      0.000000
# 25%     4345.5000      0.000000      4.000000      6.000000      0.000000
# 50%     8690.0000      1.000000      7.000000     12.000000      0.000000
# 75%    13034.5000      1.000000     10.000000     18.000000      0.000000
# max    17379.0000      1.000000     12.000000     23.000000      1.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       3.003683      0.682721      1.425283      0.496987      0.475775
# std        2.005771      0.465431      0.639357      0.192556      0.171850
# min        0.000000      0.000000      1.000000      0.020000      0.000000
# 25%        1.000000      0.000000      1.000000      0.340000      0.333300
# 50%        3.000000      1.000000      1.000000      0.500000      0.484800
# 75%        5.000000      1.000000      2.000000      0.660000      0.621200
# max        6.000000      1.000000      4.000000      1.000000      1.000000
#
#                 hum     windspeed        casual    registered           cnt  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.627229      0.190098     35.676218    153.786869    189.463088
# std        0.192930      0.122340     49.305030    151.357286    181.387599
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.480000      0.104500      4.000000     34.000000     40.000000
# 50%        0.630000      0.194000     17.000000    115.000000    142.000000
# 75%        0.780000      0.253700     48.000000    220.000000    281.000000
# max        1.000000      0.850700    367.000000    886.000000    977.000000
#
#             tem_cel     atemp_cel    windspeed_
# count  17379.000000  17379.000000  17379.000000
# mean      15.872375     17.280166     13.239945
# std        9.033183     12.696745      8.269943
# min       -7.000000    -14.000000      0.000000
# 25%        8.000000      7.000000      8.000000
# 50%       16.000000     17.000000     13.000000
# 75%       24.000000     28.000000     17.000000
# max       39.000000     50.000000     57.000000

# %%
day.describe()
# Out:
#           instant          yr        mnth     holiday     weekday  workingday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    0.500684    6.519836    0.028728    2.997264    0.683995
# std    211.165812    0.500342    3.451913    0.167155    2.004787    0.465233
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%    183.500000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%    366.000000    1.000000    7.000000    0.000000    3.000000    1.000000
# 75%    548.500000    1.000000   10.000000    0.000000    5.000000    1.000000
# max    731.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.544894    0.183051    0.162961    0.142429    0.077498
# min      1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      2.000000    0.655417    0.608602    0.730209    0.233214
# max      3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt     tem_cel   atemp_cel  \
# count   731.000000   731.000000   731.000000  731.000000  731.000000
# mean    848.176471  3656.172367  4504.348837   15.774282   17.176471
# std     686.622488  1560.256377  1937.211452    8.588759   12.091672
# min       2.000000    20.000000    22.000000   -5.000000  -12.000000
# 25%     315.500000  2497.000000  3152.000000    8.000000    7.000000
# 50%     713.000000  3662.000000  4548.000000   16.000000   17.000000
# 75%    1096.000000  4776.500000  5956.000000   23.000000   28.000000
# max    3410.000000  6946.000000  8714.000000   33.000000   41.000000
#
#        windspeed_
# count  731.000000
# mean    13.262654
# std      5.190293
# min      2.000000
# 25%     10.000000
# 50%     13.000000
# 75%     16.000000
# max     35.000000

# %%
hour.head(5)
# Out:
#    instant     dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1 2011-01-01  Winter   0     1   0        0        6           0
# 1        2 2011-01-01  Winter   0     1   1        0        6           0
# 2        3 2011-01-01  Winter   0     1   2        0        6           0
# 3        4 2011-01-01  Winter   0     1   3        0        6           0
# 4        5 2011-01-01  Winter   0     1   4        0        6           0
#
#    weathersit  ...   atemp   hum  windspeed  casual  registered  cnt  \
# 0           1  ...  0.2879  0.81        0.0       3          13   16
# 1           1  ...  0.2727  0.80        0.0       8          32   40
# 2           1  ...  0.2727  0.80        0.0       5          27   32
# 3           1  ...  0.2879  0.75        0.0       3          10   13
# 4           1  ...  0.2879  0.75        0.0       0           1    1
#
#    is_holiday tem_cel  atemp_cel  windspeed_
# 0          No       4          0           0
# 1          No       3         -1           0
# 2          No       3         -1           0
# 3          No       4          0           0
# 4          No       4          0           0
#
# [5 rows x 21 columns]

# %%
day.head(5)
# Out:
#    instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1 2011-01-01  Winter   0     1        0        6           0
# 1        2 2011-01-02  Winter   0     1        0        0           0
# 2        3 2011-01-03  Winter   0     1        0        1           1
# 3        4 2011-01-04  Winter   0     1        0        2           1
# 4        5 2011-01-05  Winter   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt is_holiday  tem_cel  atemp_cel  windspeed_
# 0   985         No        9          7          11
# 1   801         No       10          8          17
# 2  1349         No        2         -3          17
# 3  1562         No        2         -2          11
# 4  1600         No        3         -1          13

# %%
fig,axs=plt.subplots(1,2,sharey=True)
axs[0].set_title("weathersit")
axs[1].set_title("windspeed")

axs[0].hist(hour["windspeed"],bins=10)
axs[1].hist(hour["weathersit"],bins=10)

plt.show()

# %%
fig,axs=plt.subplots(1,2,figsize=(20,10))

sns.scatterplot(data=hour[hour["yr"]==0],y="cnt",x="dteday",hue="tem_cel",palette="coolwarm",ax=axs[0])
sns.scatterplot(data=hour[hour["yr"]==1],y="cnt",x="dteday",hue="tem_cel",palette="coolwarm",ax=axs[1])
plt.show()

# %%
fig,axs=plt.subplots(1,2,figsize=(20,10))

sns.scatterplot(data=day[hour["yr"]==0],y="cnt",x="dteday",hue="tem_cel",palette="coolwarm",ax=axs[0])
sns.scatterplot(data=day[hour["yr"]==1],y="cnt",x="dteday",hue="tem_cel",palette="coolwarm",ax=axs[1])
plt.show()
# Out:
# /var/folders/1j/30cgkc_x275_pj48vlh0dgz00000gn/T/ipykernel_1283/2097974629.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=day[hour["yr"]==0],y="cnt",x="dteday",hue="tem_cel",palette="coolwarm",ax=axs[0])
# /var/folders/1j/30cgkc_x275_pj48vlh0dgz00000gn/T/ipykernel_1283/2097974629.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.scatterplot(data=day[hour["yr"]==1],y="cnt",x="dteday",hue="tem_cel",palette="coolwarm",ax=axs[1])

# %%
fig,ax=plt.subplots(figsize=(20,6))
sns.boxplot(data=hour[hour["yr"]==1],y="cnt",x="weathersit",hue="tem_cel")
plt.title("")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,6))
sns.boxplot(data=day[day["yr"]==1],y="cnt",x="weathersit",hue="tem_cel")
plt.title("")
plt.show()

# %%
fig,axs=plt.subplots(1,2,figsize=(20,6),sharey=True)
axs[0].set_title("")
axs[1].set_title("")
sns.boxplot(data=hour[hour["yr"]==1],y="casual",x="weathersit",hue="tem_cel",ax=axs[0])
sns.boxplot(data=hour[hour["yr"]==1],y="registered",x="weathersit",hue="tem_cel",ax=axs[1])
plt.title("")
plt.show()

# %%
fig,axs=plt.subplots(1,2,figsize=(20,6),sharey=True)
axs[0].set_title("")
axs[1].set_title("")
sns.boxplot(data=day[day["yr"]==1],y="casual",x="weathersit",hue="tem_cel",ax=axs[0])
sns.boxplot(data=day[day["yr"]==1],y="registered",x="weathersit",hue="tem_cel",ax=axs[1])
plt.title("")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,6))
sns.boxplot(data=hour[hour["yr"]==1],y="registered",x="weathersit",hue="tem_cel")
plt.title("")
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,6))
sns.boxplot(data=day[day["yr"]==1],y="registered",x="weathersit",hue="tem_cel")
plt.title("")
plt.show()

# %%
weather=hour[["weathersit","temp","hum","windspeed","registered"]].copy()

matrix_weather=weather.corr()


fig,axs=plt.subplots(1,3,figsize=(6,6))
fig,ax=plt.subplots(figsize=(6,6))
sns.heatmap(data=matrix_weather,cmap="coolwarm",vmin=-1,vmax=1,robust=True,square=True,annot=True )
plt.show()

# %%
weather=day[["weathersit","temp","hum","windspeed","registered"]].copy()

matrix_weather=weather.corr()


fig,axs=plt.subplots(1,3,figsize=(6,6))
fig,ax=plt.subplots(figsize=(6,6))
sns.heatmap(data=matrix_weather,cmap="coolwarm",vmin=-1,vmax=1,robust=True,square=True,annot=True )
plt.show()

# %%
fig,axs=plt.subplots(figsize=(15,6))
sns.boxplot(data=hour,x="hr",y="cnt",hue="season")
plt.show()

# %%
fig,axs=plt.subplots(3,1,figsize=(16,15),sharey=True)
axs[0].set_title("Trips of all user groups")
axs[2].set_title("Trips of casual users")
axs[1].set_title("Trips of registered users")
axs[0].set(xlabel="",ylabel="mean")
axs[2].set(xlabel="",ylabel="mean")
axs[1].set(xlabel="",ylabel="mean")
axs[0].set_xlim(0,24)
axs[0].set_xticks(range(0,24))
axs[1].set_xlim(0,24)
axs[1].set_xticks(range(0,24))
axs[2].set_xlim(0,24)
axs[2].set_xticks(range(0,24))
sns.lineplot(data=hour,x="hr",y="cnt",hue="season",markers=True,estimator=np.mean,ax=axs[0])
sns.lineplot(data=hour,x="hr",y="registered",hue="season",markers=True,estimator=np.mean,ax=axs[1],legend=None)
sns.lineplot(data=hour,x="hr",y="casual",hue="season",markers=True,estimator=np.mean,ax=axs[2],legend=None)


plt.show()

# %%
hour.describe()
# Out:
#           instant            yr          mnth            hr       holiday  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      0.502561      6.537775     11.546752      0.028770
# std     5017.0295      0.500008      3.438776      6.914405      0.167165
# min        1.0000      0.000000      1.000000      0.000000      0.000000
# 25%     4345.5000      0.000000      4.000000      6.000000      0.000000
# 50%     8690.0000      1.000000      7.000000     12.000000      0.000000
# 75%    13034.5000      1.000000     10.000000     18.000000      0.000000
# max    17379.0000      1.000000     12.000000     23.000000      1.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       3.003683      0.682721      1.425283      0.496987      0.475775
# std        2.005771      0.465431      0.639357      0.192556      0.171850
# min        0.000000      0.000000      1.000000      0.020000      0.000000
# 25%        1.000000      0.000000      1.000000      0.340000      0.333300
# 50%        3.000000      1.000000      1.000000      0.500000      0.484800
# 75%        5.000000      1.000000      2.000000      0.660000      0.621200
# max        6.000000      1.000000      4.000000      1.000000      1.000000
#
#                 hum     windspeed        casual    registered           cnt  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.627229      0.190098     35.676218    153.786869    189.463088
# std        0.192930      0.122340     49.305030    151.357286    181.387599
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.480000      0.104500      4.000000     34.000000     40.000000
# 50%        0.630000      0.194000     17.000000    115.000000    142.000000
# 75%        0.780000      0.253700     48.000000    220.000000    281.000000
# max        1.000000      0.850700    367.000000    886.000000    977.000000
#
#             tem_cel     atemp_cel    windspeed_
# count  17379.000000  17379.000000  17379.000000
# mean      15.872375     17.280166     13.239945
# std        9.033183     12.696745      8.269943
# min       -7.000000    -14.000000      0.000000
# 25%        8.000000      7.000000      8.000000
# 50%       16.000000     17.000000     13.000000
# 75%       24.000000     28.000000     17.000000
# max       39.000000     50.000000     57.000000

# %%
day.describe()
# Out:
#           instant          yr        mnth     holiday     weekday  workingday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    0.500684    6.519836    0.028728    2.997264    0.683995
# std    211.165812    0.500342    3.451913    0.167155    2.004787    0.465233
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%    183.500000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%    366.000000    1.000000    7.000000    0.000000    3.000000    1.000000
# 75%    548.500000    1.000000   10.000000    0.000000    5.000000    1.000000
# max    731.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.544894    0.183051    0.162961    0.142429    0.077498
# min      1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      2.000000    0.655417    0.608602    0.730209    0.233214
# max      3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt     tem_cel   atemp_cel  \
# count   731.000000   731.000000   731.000000  731.000000  731.000000
# mean    848.176471  3656.172367  4504.348837   15.774282   17.176471
# std     686.622488  1560.256377  1937.211452    8.588759   12.091672
# min       2.000000    20.000000    22.000000   -5.000000  -12.000000
# 25%     315.500000  2497.000000  3152.000000    8.000000    7.000000
# 50%     713.000000  3662.000000  4548.000000   16.000000   17.000000
# 75%    1096.000000  4776.500000  5956.000000   23.000000   28.000000
# max    3410.000000  6946.000000  8714.000000   33.000000   41.000000
#
#        windspeed_
# count  731.000000
# mean    13.262654
# std      5.190293
# min      2.000000
# 25%     10.000000
# 50%     13.000000
# 75%     16.000000
# max     35.000000

# %%
hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  category
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
#  17  is_holiday  17379 non-null  category
#  18  tem_cel     17379 non-null  int64
#  19  atemp_cel   17379 non-null  int64
#  20  windspeed_  17379 non-null  int64
# dtypes: category(2), datetime64[ns](1), float64(4), int64(14)
# memory usage: 2.6 MB

# %%
day.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    category
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
#  16  is_holiday  731 non-null    category
#  17  tem_cel     731 non-null    int64
#  18  atemp_cel   731 non-null    int64
#  19  windspeed_  731 non-null    int64
# dtypes: category(2), datetime64[ns](1), float64(4), int64(13)
# memory usage: 104.7 KB
